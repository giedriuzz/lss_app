# %%
import sys
import os

# Add the parent directory of 'dictionaries' to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))

from src.dictionaries.raports import raport

testing_type = raport[0]['salta']
testing_len = raport[0]
print(f'tipas: {type((testing_type))}')
print(f'reikšmė: {testing_type}')
print(f'ilgis: {len(testing_len)}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 # Add the parent directory of 'dictionaries' to the Python path
#       5 sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
# ----> 7 from src.dictionaries.raports import raport
#       9 testing_type = raport[0]['salta']
#      10 testing_len = raport[0]
#
# ModuleNotFoundError: No module named 'src'
